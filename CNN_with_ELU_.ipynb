# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyaMF/Analysis-of-Activation-Functions-in-CNN/blob/master/CNN_with_ELU_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #         ANALYSIS OF ACTIVATION FUNCTIONS IN CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# In this project , I'll train a CNN to classify images from the CIFAR-10 database. The CNN defiend with Elu activation function
# ![image.png](data:image/png;base64,...)

# %%
# !pip install livelossplot --quiet
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)

# %%
#Load Libraries 
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from livelossplot import PlotLosses

# %% [markdown]
# **Utilize GPUs for computation by using TORCH.CUDA package**.

# %%
# Check if CUDA available to process data in parallel and spead training time
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# **Load CIFAR-10 Database**

# %%
# number of subprocesses 
num_workers = 0
# number of samples per batch 
batch_size = 20
# percentage of validation set from training set 
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
     # Data Agumentation                           
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),  # convert images to tensors data types
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # normlize RGB values to be between 0-1
    ])

#  Split data
# define the training datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
# define the test datasets
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# specify the 10 image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %% [markdown]
# **Visualize Data**

# %%
# %matplotlib inline

def imshow(img):
  # function to display an image
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image to numpy type for visualization

# get one batch of training images to display them 
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# **Define a CNN architecture**

# %% [markdown]
# ![CNN](https://www.researchgate.net/profile/Takio_Kurita/publication/320748406/figure/fig1/AS:555719381274624@1509505233044/An-example-of-CNN-architecture.png)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # 1- define convolutional layers in the __init__ function: self.conv = nn.Conv2d(input_depth,Output_depth,Kernel_size, padding)
        # convolutional layer (sees 32x32x3 image tensor) 
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1) # output will be 32 *32 size
        # convolutional layer (sees 16x16x16 tensor)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1) # output will be 16 *16 size
        # convolutional layer (sees 8x8x32 tensor)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1) # output will be 8 *8 size
        # convolutional layer (sees 8x8x32 tensor)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1) # output will be 4 *4 size

        # 2- define max pooling layer in the __init__ function: self.pool = nn.MaxPool2d(Kernel_size,stride)
        self.pool = nn.MaxPool2d(2, 2)

        # 3- define fully connected layers in the __init__ function: self.fc = nn.Linear(64 * 4 * 4, 500)
        self.fc1 = nn.Linear(128 * 2 * 2, 500)
        # linear layer (500 -> 10)
        self.fc2 = nn.Linear(500, 10)

        # To reduce overfitting dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
       
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.elu(self.conv1(x), alpha=1.0, inplace=False))  # passing in an input image x and applying a ReLU function to the output of this layer then that poling layer being applied.
        x = self.pool(F.elu(self.conv2(x), alpha=1.0, inplace=False))  
        x = self.pool(F.elu(self.conv3(x), alpha=1.0, inplace=False)) 
        x = self.pool(F.elu(self.conv4(x), alpha=1.0, inplace=False)) 
        # flatten image input
        x = x.view(-1, 128 * 2 * 2)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = F.elu(self.fc1(x), alpha=1.0, inplace=False)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = self.fc2(x)
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# model summary
summary(model, input_size=(3, 32, 32))
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=512, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          MaxPool2d-2           [-1, 16, 16, 16]               0
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#          MaxPool2d-4             [-1, 32, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#          MaxPool2d-6             [-1, 64, 4, 4]               0
#             Conv2d-7            [-1, 128, 4, 4]          73,856
#          MaxPool2d-8            [-1, 128, 2, 2]               0
#            Dropout-9                  [-1, 512]               0
#            Linear-10                  [-1, 500]         256,500
#           Dropout-11                  [-1, 500]               0
#            Linear-12                   [-1, 10]           5,010
# ================================================================
# Total params: 358,950
# Trainable params: 358,950
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.30
# Params size (MB): 1.37
# Estimated Total Size (MB): 1.69
# ----------------------------------------------------------------

# %% [markdown]
# **Define the loss and optimizer**

# %%
# determine loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()
# determine weight optimizer 
optimizer = optim.SGD(model.parameters(), lr=0.01)

# SGD is a simple modification to the standard gradient descent algorithm that computes the gradient 
# & updates weights on small batches of training data, rather than the entire training set itself.

# %% [markdown]
# **Train the Network**

# %% [markdown]
# 1. 30 Epochs

# %%
# number of epochs to train the model
n_epochs = 30

valid_loss_min = np.Inf # track change in validation loss


for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
   
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
 
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))

    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_30epochs.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 82307.221310 	Validation Loss: 18121.438715
# Validation loss decreased (inf --> 18121.438715).  Saving model ...
# Epoch: 2 	Training Loss: 65800.172291 	Validation Loss: 15008.549538
# Validation loss decreased (18121.438715 --> 15008.549538).  Saving model ...
# Epoch: 3 	Training Loss: 58204.069558 	Validation Loss: 13629.896193
# Validation loss decreased (15008.549538 --> 13629.896193).  Saving model ...
# Epoch: 4 	Training Loss: 53252.740532 	Validation Loss: 12599.053690
# Validation loss decreased (13629.896193 --> 12599.053690).  Saving model ...
# Epoch: 5 	Training Loss: 49414.545680 	Validation Loss: 11749.520763
# Validation loss decreased (12599.053690 --> 11749.520763).  Saving model ...
# Epoch: 6 	Training Loss: 46190.863251 	Validation Loss: 10973.979545
# Validation loss decreased (11749.520763 --> 10973.979545).  Saving model ...
# Epoch: 7 	Training Loss: 43303.700766 	Validation Loss: 10227.819076
# Validation loss decreased (10973.979545 --> 10227.819076).  Saving model ...
# Epoch: 8 	Training Loss: 41010.668216 	Validation Loss: 9797.541853
# Validation loss decreased (10227.819076 --> 9797.541853).  Saving model ...
# Epoch: 9 	Training Loss: 38886.618000 	Validation Loss: 9359.304278
# Validation loss decreased (9797.541853 --> 9359.304278).  Saving model ...
# Epoch: 10 	Training Loss: 37236.445589 	Validation Loss: 9060.894903
# Validation loss decreased (9359.304278 --> 9060.894903).  Saving model ...
# Epoch: 11 	Training Loss: 35774.403481 	Validation Loss: 8666.556212
# Validation loss decreased (9060.894903 --> 8666.556212).  Saving model ...
# Epoch: 12 	Training Loss: 34353.071961 	Validation Loss: 8428.905110
# Validation loss decreased (8666.556212 --> 8428.905110).  Saving model ...
# Epoch: 13 	Training Loss: 33357.555292 	Validation Loss: 8310.566426
# Validation loss decreased (8428.905110 --> 8310.566426).  Saving model ...
# Epoch: 14 	Training Loss: 32606.281567 	Validation Loss: 7961.231002
# Validation loss decreased (8310.566426 --> 7961.231002).  Saving model ...
# Epoch: 15 	Training Loss: 31403.284832 	Validation Loss: 7905.500212
# Validation loss decreased (7961.231002 --> 7905.500212).  Saving model ...
# Epoch: 16 	Training Loss: 30442.988406 	Validation Loss: 7770.166427
# Validation loss decreased (7905.500212 --> 7770.166427).  Saving model ...
# Epoch: 17 	Training Loss: 30056.447193 	Validation Loss: 7725.248984
# Validation loss decreased (7770.166427 --> 7725.248984).  Saving model ...
# Epoch: 18 	Training Loss: 29378.551270 	Validation Loss: 7398.255590
# Validation loss decreased (7725.248984 --> 7398.255590).  Saving model ...
# Epoch: 19 	Training Loss: 28825.995070 	Validation Loss: 7393.028284
# Validation loss decreased (7398.255590 --> 7393.028284).  Saving model ...
# Epoch: 20 	Training Loss: 28016.850279 	Validation Loss: 7439.535474
# Epoch: 21 	Training Loss: 27683.095326 	Validation Loss: 7369.218757
# Validation loss decreased (7393.028284 --> 7369.218757).  Saving model ...
# Epoch: 22 	Training Loss: 26898.026802 	Validation Loss: 7354.507301
# Validation loss decreased (7369.218757 --> 7354.507301).  Saving model ...
# Epoch: 23 	Training Loss: 26638.650689 	Validation Loss: 7079.315757
# Validation loss decreased (7354.507301 --> 7079.315757).  Saving model ...
# Epoch: 24 	Training Loss: 26285.476127 	Validation Loss: 7308.440768
# Epoch: 25 	Training Loss: 25542.280657 	Validation Loss: 7094.659403
# Epoch: 26 	Training Loss: 25440.422413 	Validation Loss: 6966.732616
# Validation loss decreased (7079.315757 --> 6966.732616).  Saving model ...
# Epoch: 27 	Training Loss: 24955.835148 	Validation Loss: 6920.840480
# Validation loss decreased (6966.732616 --> 6920.840480).  Saving model ...
# Epoch: 28 	Training Loss: 24520.555909 	Validation Loss: 6877.775580
# Validation loss decreased (6920.840480 --> 6877.775580).  Saving model ...
# Epoch: 29 	Training Loss: 24210.641270 	Validation Loss: 7061.485388
# Epoch: 30 	Training Loss: 23989.022422 	Validation Loss: 6939.350196

# %% [markdown]
# **Load the Model**

# %%
model.load_state_dict(torch.load('model_30epochs.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Test the Network**

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
  
    


# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))



for i in range(10):
    if class_total[i] > 0:
         #accurecy = correct_true / number_of_classified_images
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
        #recall = correct_true / number_of_actual_true   #number of actual true in each class =1000
        print('Test recall of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / 1000 ,
            np.sum(class_correct[i]), 1000))
      
        
        print('\n ***')
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.685781
#
# Test Accuracy of airplane: 75% (758/1000)
# Test recall of airplane: 75% (758/1000)
#
#  ***
# Test Accuracy of automobile: 85% (853/1000)
# Test recall of automobile: 85% (853/1000)
#
#  ***
# Test Accuracy of  bird: 62% (627/1000)
# Test recall of  bird: 62% (627/1000)
#
#  ***
# Test Accuracy of   cat: 51% (513/1000)
# Test recall of   cat: 51% (513/1000)
#
#  ***
# Test Accuracy of  deer: 81% (815/1000)
# Test recall of  deer: 81% (815/1000)
#
#  ***
# Test Accuracy of   dog: 69% (692/1000)
# Test recall of   dog: 69% (692/1000)
#
#  ***
# Test Accuracy of  frog: 84% (842/1000)
# Test recall of  frog: 84% (842/1000)
#
#  ***
# Test Accuracy of horse: 82% (822/1000)
# Test recall of horse: 82% (822/1000)
#
#  ***
# Test Accuracy of  ship: 89% (897/1000)
# Test recall of  ship: 89% (897/1000)
#
#  ***
# Test Accuracy of truck: 81% (817/1000)
# Test recall of truck: 81% (817/1000)
#
#  ***
#
# Test Accuracy (Overall): 76% (7636/10000)

# %% [markdown]
# **Visualize Test Results**

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))

# %% [markdown]
# 2. 50 Epochs

# %%
# number of epochs to train the model
n_epochs = 50

valid_loss_min = np.Inf # track change in validation loss


for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
   
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
 
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))

    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_50epochs.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 24120.533877 	Validation Loss: 6797.471116
# Validation loss decreased (inf --> 6797.471116).  Saving model ...
# Epoch: 2 	Training Loss: 23990.000760 	Validation Loss: 6888.902809
# Epoch: 3 	Training Loss: 23550.819019 	Validation Loss: 6907.375851
# Epoch: 4 	Training Loss: 23116.709590 	Validation Loss: 6718.147077
# Validation loss decreased (6797.471116 --> 6718.147077).  Saving model ...
# Epoch: 5 	Training Loss: 23237.911324 	Validation Loss: 6870.728065
# Epoch: 6 	Training Loss: 22834.342738 	Validation Loss: 6785.600547
# Epoch: 7 	Training Loss: 22380.765013 	Validation Loss: 6881.383123
# Epoch: 8 	Training Loss: 22308.074409 	Validation Loss: 6692.780260
# Validation loss decreased (6718.147077 --> 6692.780260).  Saving model ...
# Epoch: 9 	Training Loss: 21960.912517 	Validation Loss: 6711.639031
# Epoch: 10 	Training Loss: 21838.462776 	Validation Loss: 6436.052492
# Validation loss decreased (6692.780260 --> 6436.052492).  Saving model ...
# Epoch: 11 	Training Loss: 21314.919169 	Validation Loss: 6437.849328
# Epoch: 12 	Training Loss: 21280.487135 	Validation Loss: 6506.363887
# Epoch: 13 	Training Loss: 21058.803095 	Validation Loss: 6543.742799
# Epoch: 14 	Training Loss: 20614.590095 	Validation Loss: 6426.303250
# Validation loss decreased (6436.052492 --> 6426.303250).  Saving model ...
# Epoch: 15 	Training Loss: 20453.165251 	Validation Loss: 6412.083655
# Validation loss decreased (6426.303250 --> 6412.083655).  Saving model ...
# Epoch: 16 	Training Loss: 20304.380933 	Validation Loss: 6464.614806
# Epoch: 17 	Training Loss: 20124.651534 	Validation Loss: 6553.851675
# Epoch: 18 	Training Loss: 20202.846126 	Validation Loss: 6466.947791
# Epoch: 19 	Training Loss: 19868.050869 	Validation Loss: 6957.797095
# Epoch: 20 	Training Loss: 19619.731315 	Validation Loss: 6479.890479
# Epoch: 21 	Training Loss: 19469.679721 	Validation Loss: 6572.099124
# Epoch: 22 	Training Loss: 19315.137987 	Validation Loss: 6259.744120
# Validation loss decreased (6412.083655 --> 6259.744120).  Saving model ...
# Epoch: 23 	Training Loss: 19259.121306 	Validation Loss: 6425.047227
# Epoch: 24 	Training Loss: 19025.046993 	Validation Loss: 6308.817352
# Epoch: 25 	Training Loss: 18833.384926 	Validation Loss: 6263.694659
# Epoch: 26 	Training Loss: 18725.459417 	Validation Loss: 6649.808674
# Epoch: 27 	Training Loss: 18563.517570 	Validation Loss: 6646.144601
# Epoch: 28 	Training Loss: 18614.746480 	Validation Loss: 6415.656949
# Epoch: 29 	Training Loss: 18383.618691 	Validation Loss: 6392.903519
# Epoch: 30 	Training Loss: 18091.031721 	Validation Loss: 6561.140257
# Epoch: 31 	Training Loss: 18125.955940 	Validation Loss: 6393.330871
# Epoch: 32 	Training Loss: 17961.453219 	Validation Loss: 6373.349379
# Epoch: 33 	Training Loss: 17597.401597 	Validation Loss: 6308.381206
# Epoch: 34 	Training Loss: 17566.381691 	Validation Loss: 6460.406779
# Epoch: 35 	Training Loss: 17386.388732 	Validation Loss: 6369.884440
# Epoch: 36 	Training Loss: 17322.154920 	Validation Loss: 6390.366267
# Epoch: 37 	Training Loss: 17150.480192 	Validation Loss: 6262.806299
# Epoch: 38 	Training Loss: 17182.057284 	Validation Loss: 6318.027623
# Epoch: 39 	Training Loss: 16945.511287 	Validation Loss: 6381.673685
# Epoch: 40 	Training Loss: 16962.062368 	Validation Loss: 6138.939955
# Validation loss decreased (6259.744120 --> 6138.939955).  Saving model ...
# Epoch: 41 	Training Loss: 16503.312779 	Validation Loss: 6596.712906
# Epoch: 42 	Training Loss: 16767.745319 	Validation Loss: 6551.591571
# Epoch: 43 	Training Loss: 16408.802258 	Validation Loss: 6309.433431
# Epoch: 44 	Training Loss: 16281.931506 	Validation Loss: 6477.288301
# Epoch: 45 	Training Loss: 16248.727677 	Validation Loss: 6189.856433
# Epoch: 46 	Training Loss: 16452.715240 	Validation Loss: 6323.657975
# Epoch: 47 	Training Loss: 16129.669280 	Validation Loss: 6397.434411
# Epoch: 48 	Training Loss: 15992.584342 	Validation Loss: 6462.700391
# Epoch: 49 	Training Loss: 15931.143535 	Validation Loss: 6324.275251
# Epoch: 50 	Training Loss: 15937.476805 	Validation Loss: 6382.756644

# %% [markdown]
# **Load the Model**

# %%
model.load_state_dict(torch.load('model_50epochs.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Test the Network**

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))
for i in range(10):
    if class_total[i] > 0:
         #accurecy = correct_true / number_of_classified_images
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
        #recall = correct_true / number_of_actual_true   #number of actual true in each class =1000
        print('Test recall of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / 1000 ,
            np.sum(class_correct[i]), 1000))
      
        
        print('\n ***')
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.633257
#
# Test Accuracy of airplane: 78% (786/1000)
# Test recall of airplane: 78% (786/1000)
#
#  ***
# Test Accuracy of automobile: 89% (898/1000)
# Test recall of automobile: 89% (898/1000)
#
#  ***
# Test Accuracy of  bird: 71% (710/1000)
# Test recall of  bird: 71% (710/1000)
#
#  ***
# Test Accuracy of   cat: 65% (651/1000)
# Test recall of   cat: 65% (651/1000)
#
#  ***
# Test Accuracy of  deer: 78% (780/1000)
# Test recall of  deer: 78% (780/1000)
#
#  ***
# Test Accuracy of   dog: 69% (693/1000)
# Test recall of   dog: 69% (693/1000)
#
#  ***
# Test Accuracy of  frog: 85% (851/1000)
# Test recall of  frog: 85% (851/1000)
#
#  ***
# Test Accuracy of horse: 81% (811/1000)
# Test recall of horse: 81% (811/1000)
#
#  ***
# Test Accuracy of  ship: 89% (892/1000)
# Test recall of  ship: 89% (892/1000)
#
#  ***
# Test Accuracy of truck: 86% (864/1000)
# Test recall of truck: 86% (864/1000)
#
#  ***
#
# Test Accuracy (Overall): 79% (7936/10000)

# %% [markdown]
# **Visualize Test Results**

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
